# %%
Plot[Sin[x], {x, 0, 10}]
# Out:
# -Graphics-

# %%
Integrate[Sin[x]^2, x]
# Out:
# x   Sin[2 x]
# - - --------
# 2      4

# %%
DSolve[y''[x] + y[x] == 0, y[x], x]
# Out:
# {{y[x] -> C[1] Cos[x] + C[2] Sin[x]}}

# %%
Manipulate[

 Plot[Sin[a x], {x,0,10}],

 {a,1,10}

]
# Out:
# Manipulate[Plot[Sin[a x], {x, 0, 10}], {a, 1, 10}]

# %%
Integrate[x Exp[x], x]
# Out:
#  x
# E  (-1 + x)

# %%
Needs["Wolfram`Alpha`"]

WolframAlpha[

 "integrate x Exp[x] dx step by step",

 {{"Input", 1}, {"IndefiniteIntegral", 2}, "Content"}

]
# Out:
# Get::noopen: Cannot open Wolfram`Alpha`.
# Needs::nocont: Context Wolfram`Alpha` was not created when Needs was evaluated.
# WolframAlpha::format: {{Input, 1}, {IndefiniteIntegral, 2}, Content} is not a recognized WolframAlpha format.
# $Failed
# WolframAlpha[integrate x Exp[x] dx step by step,
#
# >   {{Input, 1}, {IndefiniteIntegral, 2}, Content}]

# %%
WolframAlpha[
 "simplify Sin[x]^2 + Cos[x]^2 step by step",
 {{"Result", 1}, "Content"}
]
# Out:
# RawBoxes[StyleBox[FormBox[PaneBox[TagBox[1, HoldForm], FrameMargins -> 1],
#
# >     TraditionalForm], Output, GraphicsBoxOptions ->
#
# >     {DefaultBaseStyle ->
#
#                                                                           -6
# >       {Graphics, FontColor -> GrayLevel[0], LineColor -> GrayLevel[1. 10  ],
#
# >        FontFamily -> Times}, DefaultTicksStyle ->
#
# >       Directive[FontFamily -> Times, FontSize -> 11, FontColor -> GrayLevel[0.250002],
#
# >        GraphicsTicks], DefaultFrameTicksStyle ->
#
# >       Directive[FontFamily -> Times, FontSize -> 11, FontColor -> GrayLevel[0.250003],
#
# >        GraphicsFrameTicks], DefaultFrameStyle ->
#
# >       Directive[GrayLevel[0.500002, 0.7], FontColor -> GrayLevel[0.250004],
#
# >        FontOpacity -> 1, GraphicsFrame],
#
# >      DefaultAxesStyle ->
#
# >       Directive[GrayLevel[0.500003, 0.7], FontColor -> GrayLevel[0.250005],
#
# >        FontOpacity -> 1, GraphicsAxes]},
#
# ...

# %%
u = x;
du = D[u, x]

dv = Exp[x];
v = Integrate[dv, x]
# Out:
# 1
#  x
# E

# %%
u*v - Integrate[v*du, x]
# Out:
#   x    x
# -E  + E  x
